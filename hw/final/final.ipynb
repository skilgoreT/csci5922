# %%
# %load read_data.py
# %load read_data.py
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pymongo import MongoClient

DB_HOST = '10.0.1.3'
DB_NAME = 'wootmathdev'
DB_PORT = 27017

client = MongoClient(DB_HOST, DB_PORT)
db = client[DB_NAME]
data = db['anon_student_task_responses'].find({}, {'student.student_id':1}).limit(1000)
unique_ids = set([d['student']['student_id'] for d in data])

student_vectors = []
for id in unique_ids:
  # all the entries associated with a specific student
  data = db['anon_student_task_responses'].find({'student.student_id':id})
  responses = {}
  for d in data:
    responses[d['qual_id']] = { 'correct':d['correct'], 'ts':d['t'] }

  student_vectors.append(pd.DataFrame(responses))

# The series index is the unique student id, series elements are DataFrames with cols indexed by qual_id
student_vectors = pd.Series(student_vectors, index=unique_ids)

# %%
student_vectors.head()
# Out:
# U8T3K5I3A7            096-5s8eJ6.partb.0p9xDPJH1A 096-5s8eJ6...
# 17Q1H4T7              1zsCldT4p8.set1.EFxoqDuPL- 1zsCldT4p8....
# 8W4E7E3O4             IRaIcmaWjs.partb.1JKfI4cKj9 IRaIcmaWjs...
# 3U8S3V4L7             1zsCldT4p8.set1.EFxoqDuPL- 1zsCldT4p8....
# X8T7Q6K3T7            096-5s8eJ6.partb.7s728JWh9K 096-5s8eJ6...
# dtype: object

# %%
student_vectors[0].head()
# Out:
#         096-5s8eJ6.partb.0p9xDPJH1A 096-5s8eJ6.partb.87u44sf9YD  \
# correct                        True                        True
# ts                      1.47006e+12                 1.47006e+12
#
#         096-5s8eJ6.partb.Ke8gmYmSmV 096-5s8eJ6.partb.X_shFixR4q  \
# correct                        True                        True
# ts                      1.47006e+12                 1.47006e+12
#
#         096-5s8eJ6.partb.Yt36pDZ3WP 096-5s8eJ6.partb.dW3M4_B_jY  \
# correct                        True                        True
# ts                      1.47006e+12                 1.47006e+12
#
#         096-5s8eJ6.partb.jGq7IGYWTF 096-5s8eJ6.partb.jVG3p9f-20  \
# correct                        True                        True
# ts                      1.47006e+12                 1.47006e+12
#
#         096-5s8eJ6.partb.kmZ7tVW5zt 096-5s8eJ6.partb.n6-37DIHPX  \
# correct                        True                        True
# ts                      1.47006e+12                 1.47093e+12
#
#                     ...             scdDyl48EJ.parta.bNUAfTQU37  \
# correct             ...                                    True
# ts                  ...                             1.47102e+12
#
#         scdDyl48EJ.parta.sc1IkIYrjw xBSQFgDRAs.partb.NYEE5hVYkH  \
# correct                        True                        True
# ts                      1.47102e+12                 1.47369e+12
#
#         xBSQFgDRAs.partb.PWWR5vLWNw xBSQFgDRAs.partb.cxtRMw18-c  \
# correct                        True                        True
# ts                      1.48821e+12                 1.47369e+12
#
#         xBSQFgDRAs.partb.kLcfSn6GNp xBSQFgDRAs.partb.lrO_Scst8Q  \
# correct                        True                        True
# ts                      1.47369e+12                  1.4864e+12
#
#         xBSQFgDRAs.partb.xAAloxaNNZ yHG2TZySZ6.bonus.43iqmIdm8n  \
# correct                        True                        True
# ts                      1.47369e+12                 1.47093e+12
#
#         yOAO1mViz1.bonus._m5xSo51Db
# correct                        True
# ts                      1.47853e+12
#
# [2 rows x 193 columns]
